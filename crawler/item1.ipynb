# %%
import requests
import pandas as pd

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/88.0.4324.104 Safari/537.36 '
}
target = 'https://pvp.qq.com/web201605/js/item.json'
item_list = requests.get(target).json()
item_df = pd.DataFrame(item_list)
item_df.sort_values(["item_type", "price", "item_id"], inplace=True)
item_df.fillna("", inplace=True)
item_df.des1 = item_df.des1.str.replace("</?p>", "", regex=True)
item_df.des2 = item_df.des2.str.replace("</?p>", "", regex=True)
item_df
# Out:
#      item_id item_name  item_type  price  total_price                des1  \
# 0       1111        铁剑          1    150          300             +25物理攻击
# 1       1112        匕首          1    174          290           +10%攻击速度
# 2       1113      搏击拳套          1    174          290             +8%暴击率
# 3       1114      吸血之镰          1    174          290             +8%物理吸血
# 101     1115      迅捷长矛          1    225          375  +10物理攻击<br>+5%冷却缩减
# ..       ...       ...        ...    ...          ...                 ...
# 115     1725     近卫·星泉          7   1110         1850   +1000生命值<br>+8%移速
# 113     1737     极影·形昭          7   1110         1850   +1000生命值<br>+8%移速
# 111     1747     极影·星泉          7   1110         1850   +1000生命值<br>+8%移速
# 116     1753     近卫·奔狼          7   1110         1850   +1000生命值<br>+8%移速
# 117     1754     近卫·形昭          7   1110         1850   +1000生命值<br>+8%移速
#
#                                                   des2
# 0
# 1
# 2
# 3
# 101
# ..                                                 ...
# 115  主动-星芒：与范围内的一名友方英雄（默认为血量最低）建立链接，5秒内回复双方（500~106...
# 113  主动-见影：释放一道探照光波，对1200范围内的敌方造成4次伤害，每次造成当前生命3%的法术...
# 111  主动-星芒：与范围内的一名友方英雄（默认为血量最低）建立链接，5秒内回复双方（500~106...
# 116  主动-奔腾号令：范围内友方英雄增加移动速度，最高增加100%~200%移动速度，持续5秒，途...
# 117  主动-见影：释放一道探照光波，对1200范围内的敌方造成4次伤害，每次造成当前生命3%的伤害...
#
# [119 rows x 7 columns]
